# %%
from pathlib import Path
import pandas
import numpy as np

def process_csv(input_path, output_path):
    df = pandas.read_csv(input_path)
    df = df.drop('ts', axis=1)
    df["Time (s)"] = df["t_s"].round(2)
    features_df = (df.pivot_table(
            index="Time (s)",
            columns="counter_name",
            values="value",
            aggfunc="mean", # if multiple rows have same counter_name and time bin, mean value is used
            observed=True)
          .sort_index())
    features_df = features_df.reset_index()
    features_df.columns.name = None
    features_df = features_df.replace(0, np.nan)
    features_df = features_df.dropna(axis=1, how='all')
    features_df = features_df.ffill()
    features_df = features_df.bfill()
    features_df = features_df.dropna(axis=1, how='any')
    features_df = features_df[features_df['Time (s)'] >= 7]
    if features_df.shape[1] >= 50:
        features_df.to_csv(output_path, index=False)

to_clean = Path("meta_scan_csvs/uncleaned/pre_update")
cleaned_base = Path("meta_scan_csvs/cleaned")
for csv_file in to_clean.rglob("*.csv"):
    relative_path = csv_file.relative_to(to_clean)
    output_file = cleaned_base / relative_path.parent / f"{csv_file.stem}_cleaned.csv"
    print(f"Processing {csv_file.relative_to(to_clean)}...")
    output_file.parent.mkdir(parents=True, exist_ok=True)
    process_csv(csv_file, output_file)
    print(f"Created {output_file.name}\n")
# Out:
# Processing blinds\blinds_motion_1.csv...
# Created blinds_motion_1_cleaned.csv
#
# Processing blinds\blinds_motion_2.csv...
# Created blinds_motion_2_cleaned.csv
#
# Processing blinds\blinds_motion_3.csv...
# Created blinds_motion_3_cleaned.csv
#
# Processing blinds\blinds_motion_4.csv...
# Created blinds_motion_4_cleaned.csv
#
# Processing blinds\blinds_motion_5.csv...
# Created blinds_motion_5_cleaned.csv
#
# Processing blinds\blinds_object_1.csv...
# Created blinds_object_1_cleaned.csv
#
# Processing blinds\blinds_object_2.csv...
# Created blinds_object_2_cleaned.csv
#
# Processing blinds\blinds_object_3.csv...
# Created blinds_object_3_cleaned.csv
#
# Processing blinds\blinds_object_4.csv...
# Created blinds_object_4_cleaned.csv
#
# Processing blinds\blinds_object_5.csv...
# Created blinds_object_5_cleaned.csv
#
# Processing blinds\blinds_person_1.csv...
# Created blinds_person_1_cleaned.csv
#
# Processing blinds\blinds_person_2.csv...
# Created blinds_person_2_cleaned.csv
#
# Processing blinds\blinds_person_3.csv...
# Created blinds_person_3_cleaned.csv
#
# Processing blinds\blinds_person_4.csv...
# Created blinds_person_4_cleaned.csv
#
# Processing blinds\blinds_person_5.csv...
# Created blinds_person_5_cleaned.csv
#
# Processing blinds_up\blinds_up_object_1.csv...
# Created blinds_up_object_1_cleaned.csv
#
# Processing blinds_up\blinds_up_object_2.csv...
# Created blinds_up_object_2_cleaned.csv
#
# Processing blinds_up\blinds_up_object_3.csv...
# Created blinds_up_object_3_cleaned.csv
#
# Processing blinds_up\blinds_up_object_4.csv...
# Created blinds_up_object_4_cleaned.csv
#
# Processing blinds_up\blinds_up_object_5.csv...
# Created blinds_up_object_5_cleaned.csv
#
# Processing hallway\hallway_1.csv...
# Created hallway_1_cleaned.csv
#
# Processing hallway\hallway_2.csv...
# Created hallway_2_cleaned.csv
#
# Processing hallway\hallway_3.csv...
# Created hallway_3_cleaned.csv
#
# Processing hallway\hallway_4.csv...
# Created hallway_4_cleaned.csv
#
# Processing hallway\hallway_5.csv...
# Created hallway_5_cleaned.csv
#
# Processing hallway\hallway_motion_1.csv...
# Created hallway_motion_1_cleaned.csv
#
# Processing hallway\hallway_motion_2.csv...
# Created hallway_motion_2_cleaned.csv
#
# Processing hallway\hallway_motion_3.csv...
# Created hallway_motion_3_cleaned.csv
#
# Processing hallway\hallway_motion_4.csv...
# Created hallway_motion_4_cleaned.csv
#
# Processing hallway\hallway_motion_5.csv...
# Created hallway_motion_5_cleaned.csv
#
# Processing hallway\hallway_object_1.csv...
# Created hallway_object_1_cleaned.csv
#
# Processing hallway\hallway_object_2.csv...
# Created hallway_object_2_cleaned.csv
#
# Processing hallway\hallway_object_3.csv...
# Created hallway_object_3_cleaned.csv
#
# Processing hallway\hallway_object_4.csv...
# Created hallway_object_4_cleaned.csv
#
# Processing hallway\hallway_object_5.csv...
# Created hallway_object_5_cleaned.csv
#
# Processing hallway\hallway_person_1.csv...
# Created hallway_person_1_cleaned.csv
#
# Processing hallway\hallway_person_2.csv...
# Created hallway_person_2_cleaned.csv
#
# Processing hallway\hallway_person_3.csv...
# Created hallway_person_3_cleaned.csv
#
# Processing hallway\hallway_person_4.csv...
# Created hallway_person_4_cleaned.csv
#
# Processing hallway\hallway_person_5.csv...
# Created hallway_person_5_cleaned.csv
#
# Processing kitchen\kitchen_1.csv...
# Created kitchen_1_cleaned.csv
#
# Processing kitchen\kitchen_10.csv...
# Created kitchen_10_cleaned.csv
#
# Processing kitchen\kitchen_2.csv...
# Created kitchen_2_cleaned.csv
#
# Processing kitchen\kitchen_3.csv...
# Created kitchen_3_cleaned.csv
#
# Processing kitchen\kitchen_4.csv...
# Created kitchen_4_cleaned.csv
#
# Processing kitchen\kitchen_5.csv...
# Created kitchen_5_cleaned.csv
#
# Processing kitchen\kitchen_6.csv...
# Created kitchen_6_cleaned.csv
#
# Processing kitchen\kitchen_7.csv...
# Created kitchen_7_cleaned.csv
#
# Processing kitchen\kitchen_8.csv...
# Created kitchen_8_cleaned.csv
#
# Processing kitchen\kitchen_9.csv...
# Created kitchen_9_cleaned.csv
#
# Processing kitchen\kitchen_motion_1.csv...
# Created kitchen_motion_1_cleaned.csv
#
# Processing kitchen\kitchen_motion_2.csv...
# Created kitchen_motion_2_cleaned.csv
#
# Processing kitchen\kitchen_motion_3.csv...
# Created kitchen_motion_3_cleaned.csv
#
# Processing kitchen\kitchen_motion_4.csv...
# Created kitchen_motion_4_cleaned.csv
#
# Processing kitchen\kitchen_motion_5.csv...
# Created kitchen_motion_5_cleaned.csv
#
# Processing kitchen\kitchen_object_1.csv...
# Created kitchen_object_1_cleaned.csv
#
# Processing kitchen\kitchen_object_2.csv...
# Created kitchen_object_2_cleaned.csv
#
# Processing kitchen\kitchen_object_3.csv...
# Created kitchen_object_3_cleaned.csv
#
# Processing kitchen\kitchen_object_4.csv...
# Created kitchen_object_4_cleaned.csv
#
# Processing kitchen\kitchen_object_5.csv...
# Created kitchen_object_5_cleaned.csv
#
# Processing kitchen\kitchen_person_1.csv...
# Created kitchen_person_1_cleaned.csv
#
# Processing kitchen\kitchen_person_2.csv...
# Created kitchen_person_2_cleaned.csv
#
# Processing kitchen\kitchen_person_3.csv...
# Created kitchen_person_3_cleaned.csv
#
# Processing kitchen\kitchen_person_4.csv...
# Created kitchen_person_4_cleaned.csv
#
# Processing kitchen\kitchen_person_5.csv...
# Created kitchen_person_5_cleaned.csv
#
# Processing lab\lab_1.csv...
# Created lab_1_cleaned.csv
#
# Processing lab\lab_2.csv...
# Created lab_2_cleaned.csv
#
# Processing lab\lab_3.csv...
# Created lab_3_cleaned.csv
#
# Processing lab\lab_4.csv...
# Created lab_4_cleaned.csv
#
# Processing lab\lab_5.csv...
# Created lab_5_cleaned.csv
#
# Processing lab\lab_motion_1.csv...
# Created lab_motion_1_cleaned.csv
#
# Processing lab\lab_motion_2.csv...
# Created lab_motion_2_cleaned.csv
#
# Processing lab\lab_motion_3.csv...
# Created lab_motion_3_cleaned.csv
#
# Processing lab\lab_motion_4.csv...
# Created lab_motion_4_cleaned.csv
#
# Processing lab\lab_motion_5.csv...
# Created lab_motion_5_cleaned.csv
#
# Processing lab\lab_object_1.csv...
# Created lab_object_1_cleaned.csv
#
# Processing lab\lab_object_2.csv...
# Created lab_object_2_cleaned.csv
#
# Processing lab\lab_object_3.csv...
# Created lab_object_3_cleaned.csv
#
# Processing lab\lab_object_4.csv...
# Created lab_object_4_cleaned.csv
#
# Processing lab\lab_object_5.csv...
# Created lab_object_5_cleaned.csv
#
# Processing lab\lab_person_1.csv...
# Created lab_person_1_cleaned.csv
#
# Processing lab\lab_person_2.csv...
# Created lab_person_2_cleaned.csv
#
# Processing lab\lab_person_3.csv...
# Created lab_person_3_cleaned.csv
#
# Processing lab\lab_person_4.csv...
# Created lab_person_4_cleaned.csv
#
# Processing lab\lab_person_5.csv...
# Created lab_person_5_cleaned.csv
